# %%
import numpy as np
import math
from scipy.stats import norm, expon, chi2, uniform
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Standard distributions sampling
# ## Ex 1.
# Use scipy to take samples from the following distributions:
# 1. Normal distribution with $\mu$=1 and $\sigma$=4,
# 2. Exponential distribution with $\lambda = \dfrac{1}{4}$,
# 3. Chi-squared distribution with 8 degrees of freedom,
# 4. Uniform distribution with borders [$-2\sqrt{3}, 6\sqrt{3}$].
#
# Compare their theoretical and sample distribution, mean and variance.

# %% [markdown]
# ###Comment
#
# The code imports the normal distribution function from the scipy.stats module, and assigns the mean (loc) and standard deviation (scale) values of 1 and 4 respectively. It then creates an x-axis range from the left to right percentile point function (ppf) values of 0.01 and 0.99, respectively. A figure and axis are created using matplotlib, and the probability density function (pdf) of the normal distribution is plotted on the axis.
#
# A sample of 1000 random variables is then generated using the rvs method, and a histogram of these variables is plotted on the same axis with the pdf. The histogram is set to be normalized to show probability density.
#
# The legend and plot are then displayed using matplotlib. The mean and variance of the normal distribution are printed using the stats method, and the mean and variance of the sample of random variables are calculated using numpy. This comparison helps to check that the sample follows the theoretical distribution.

# %%
#1. Normal
#This one I'll do for you :-)

rv_norm = norm(loc = 1, scale = 4)
x = np.linspace(rv_norm.ppf(0.01), rv_norm.ppf(0.99), 100)
fig, ax = plt.subplots(1, 1)
ax.plot(x, rv_norm.pdf(x), 'r-', lw=5, alpha=0.6, label='norm pdf')
r_norm = rv_norm.rvs(size=1000)
ax.hist(r_norm, density=True, histtype='stepfilled', alpha=0.2, bins = x[::4])


ax.legend(loc='best', frameon=False)
plt.show()

print("Distribution mean: {0}".format(rv_norm.stats(moments='m')))
print("Distribution variance: {0}".format(rv_norm.stats(moments='v')))
print("Sample mean: {0}".format(np.mean(r_norm)))
print("Sample variance: {0}".format(np.var(r_norm)))
# Out:
# Distribution mean: 1.0
# Distribution variance: 16.0
# Sample mean: 1.0108045177568215
# Sample variance: 17.03655335280151

# %% [markdown]
# ###Comment
# The code imports the exponential distribution function from the scipy.stats module, and assigns the scale parameter of 4. It then creates an x-axis range from the left to right percentile point function (ppf) values of 0.01 and 0.99, respectively. A figure and axis are created using matplotlib, and the probability density function (pdf) of the exponential distribution is plotted on the axis.
#
# A sample of 1000 random variables is then generated using the rvs method, and a histogram of these variables is plotted on the same axis with the pdf. The histogram is set to be normalized to show probability density.
#
# The legend and plot are then displayed using matplotlib. The mean and variance of the exponential distribution are printed using the stats method, and the mean and variance of the sample of random variables are calculated using numpy. This comparison helps to check that the sample follows the theoretical distribution.
#
# In this case, the scale parameter of 4 is equivalent to the lambda parameter of 14 (λ = 1/scale)

# %%
#Exponential
#here goes your code
rv_expon = expon(scale = 4)
x = np.linspace(rv_expon.ppf(0.01), rv_expon.ppf(0.99), 100)
fig, ax = plt.subplots(1, 1)
ax.plot(x, rv_expon.pdf(x), 'r-', lw=5, alpha=0.6, label='expon pdf')
r_expon = rv_expon.rvs(size=1000)
ax.hist(r_expon, density=True, histtype='stepfilled', alpha=0.2, bins = x[::4])

ax.legend(loc='best', frameon=False)
plt.show()

print("Distribution mean: {0}".format(rv_expon.stats(moments='m')))
print("Distribution variance: {0}".format(rv_expon.stats(moments='v')))
print("Sample mean: {0}".format(np.mean(r_expon)))
print("Sample variance: {0}".format(np.var(r_expon)))
#hint: expon
# Out:
# Distribution mean: 4.0
# Distribution variance: 16.0
# Sample mean: 3.8079626396179913
# Sample variance: 13.403635560739277

# %% [markdown]
# ### Comment
#
# The code imports the chi-squared distribution function from the scipy.stats module, and assigns the degrees of freedom parameter of 8. It then generates a sample of 1000 random variables using the rvs method.
#
# An x-axis range is created from the left to right percentile point function (ppf) values of 0.01 and 0.99, respectively. A figure and axis are created using matplotlib, and the probability density function (pdf) of the chi-squared distribution is plotted on the axis.
#
# A histogram of the sample of random variables is plotted on the same axis with the pdf. The histogram is set to be normalized to show probability density.
#
# The legend and plot are then displayed using matplotlib. The mean and variance of the chi-squared distribution are printed using the stats method, and the mean and variance of the sample of random variables are calculated using numpy. This comparison helps to check that the sample follows the theoretical distribution.

# %%
#chi2
#here goes your code
# Generate samples from Chi-squared distribution with 8 degrees of freedom
rv_chi2 = chi2(df = 8)
r_chi2 = rv_chi2.rvs(size=1000)

# Plot the distribution
x = np.linspace(rv_chi2.ppf(0.01), rv_chi2.ppf(0.99), 100)
fig, ax = plt.subplots(1, 1)
ax.plot(x, rv_chi2.pdf(x), 'r-', lw=5, alpha=0.6, label='chi-2 pdf')
ax.hist(r_chi2, density=True, histtype='stepfilled', alpha=0.2, bins = x[::4])
ax.legend(loc='best', frameon=False)
plt.show()

# Print the theoretical and sample mean and variance
print("Distribution mean: {0}".format(rv_chi2.stats(moments='m')))
print("Distribution variance: {0}".format(rv_chi2.stats(moments='v')))
print("Sample mean: {0}".format(np.mean(r_chi2)))
print("Sample variance: {0}".format(np.var(r_chi2)))

#hint: chi2
# Out:
# Distribution mean: 8.0
# Distribution variance: 16.0
# Sample mean: 8.304261164782728
# Sample variance: 17.17062434240971

# %% [markdown]
# ### Comment
# This code is using the ***scipy.stats*** module to generate samples from a ***uniform*** distribution.
# It sets the low and high boundaries of the uniform distribution, creates an instance of the uniform class, then generate a sample of 1000 random values using the ***rvs()*** method.
# Then it plots the theoretical probability density function (pdf) and the histogram of the sample, using matplotlib.
# It also prints the theoretical mean and variance of the distribution, as well as the sample mean and variance of the generated random values.
# The uniform distribution is defined by the two parameters, low and high, which are the lower and upper boundary of the distribution, respectively. All values between low and high are equally likely to be generated by the rvs method.

# %%
#uniform

#here goes your code
low = -2*math.sqrt(3)
high = 6*math.sqrt(3)

rv_uniform = uniform(loc=low, scale=high-low)
r_uniform = rv_uniform.rvs(size=1000)

# Plot the distribution
x = np.linspace(rv_uniform.ppf(0.01), rv_uniform.ppf(0.99), 100)
fig, ax = plt.subplots(1, 1)
ax.plot(x, rv_uniform.pdf(x), 'r-', lw=5, alpha=0.6, label='uniform pdf')
ax.hist(r_uniform, density=True, histtype='stepfilled', alpha=0.2, bins = x[::4])
ax.legend(loc='best', frameon=False)
plt.show()

# Print the theoretical and sample mean and variance
print("Distribution mean: {0}".format(rv_uniform.stats(moments='m')))
print("Distribution variance: {0}".format(rv_uniform.stats(moments='v')))
print("Sample mean: {0}".format(np.mean(r_uniform)))
print("Sample variance: {0}".format(np.var(r_uniform)))

#hint: uniform
# Out:
# Distribution mean: 3.4641016151377544
# Distribution variance: 15.999999999999998
# Sample mean: 3.483188535106657
# Sample variance: 15.465041517973951

# %% [markdown]
# # Low of large numbers. Central Limit Theorem.
# ## Ex 2.
# a) For N from 2 to 1000 draw N samples from distributions defined in Ex 1. Plot sample variance and mean against the size of the sample.

# %% [markdown]
# ### Comment
# This code is using the ***scipy.stats*** module to generate samples from the four different distributions (normal, exponential, chi-squared, and uniform) defined in the previous exercise.
#
# It sets up arrays to store the means and variances of the samples for each distribution.
#
# Then, using a for loop, it generates samples of increasing size (from 2 to 1000) for each distribution using the ***rvs()*** method, and calculates the mean and variance of each sample using numpy's ***mean()*** and ***var()*** functions.
#
# It appends the calculated mean and variance values to the appropriate arrays for each distribution.
#
# This code is demonstrating the law of large numbers and the Central Limit Theorem.
#
# The law of large numbers states that as the size of the sample increases, the sample mean will converge to the true mean of the population.
#
# The Central Limit Theorem states that regardless of the underlying population distribution, the sample mean of a large number of random samples will be approximately normally distributed.
#
# Therefore, by plotting the sample variance and mean against the size of the sample, it should be observed that the sample variance decreases as the sample size increases and the sample mean gets closer to the true mean.

# %%
#here goes your code
# Set up arrays to store the means and variances
mean_norm = []
var_norm = []
mean_expon = []
var_expon = []
mean_chi2 = []
var_chi2 = []
mean_uniform = []
var_uniform = []

for N in range(2, 1001):
    r_norm = rv_norm.rvs(size=N)
    # Calculate mean and variance of the samples
    mean_norm.append(np.mean(r_norm))
    var_norm.append(np.var(r_norm))
    
    r_expon = rv_expon.rvs(size=N)
    # Calculate mean and variance of the samples
    mean_expon.append(np.mean(r_expon))
    var_expon.append(np.var(r_expon))
    
    r_chi2 = rv_chi2.rvs(size=N)
    # Calculate mean and variance of the samples
    mean_chi2.append(np.mean(r_chi2))
    var_chi2.append(np.var(r_chi2))
    
    r_uniform = rv_uniform.rvs(size=N)
    # Calculate mean and variance of the samples
    mean_uniform.append(np.mean(r_uniform))
    var_uniform.append(np.var(r_uniform))

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle("Variances")
axs[0, 0].plot(range(2, 1001), var_norm)
axs[0, 1].plot(range(2, 1001), var_expon)
axs[1, 0].plot(range(2, 1001), var_chi2)
axs[1, 1].plot(range(2, 1001), var_uniform)

axs[0, 0].set_title("Normal")
axs[0, 1].set_title("Exponential")
axs[1, 0].set_title("Chi2")
axs[1, 1].set_title("Uniform")

for ax in axs.flat:
    ax.set(xlabel='Sample size', ylabel='Variance')
    ax.set_ylim(0, 40)

plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle("Means")
axs[0, 0].plot(range(2, 1001), mean_norm)
axs[0, 1].plot(range(2, 1001), mean_expon)
axs[1, 0].plot(range(2, 1001), mean_chi2)
axs[1, 1].plot(range(2, 1001), mean_uniform)

axs[0, 0].set_title("Normal")
axs[0, 1].set_title("Exponential")
axs[1, 0].set_title("Chi2")
axs[1, 1].set_title("Uniform")

for ax in axs.flat:
    ax.set(xlabel='Sample size', ylabel='Mean')

plt.show()

# %% [markdown]
# ## Ex 3.
# For N=1,4,9,16 draw histograms of an average over N samples taken from distributions defined in Ex 1.

# %% [markdown]
# ### Comment
#
# This code is generating histograms of the average of N samples taken from the four different distributions (normal, exponential, chi-squared, and uniform) defined in the previous exercise.
#
# It creates a figure with 4 subplots, one for each distribution.
#
# It sets up an array of N values to be used in the for loop, in this case [1, 4, 9, 16].
#
# In the for loop, it generates N samples for each distribution using the ***rvs()*** method, then calculates the mean of each set of N samples using numpy's ***mean()*** function.
#
# It plots histograms of the means for each value of N for each distribution using matplotlib's ***hist()*** function.
#
# The histograms show how the distribution of means changes as the sample size increases. As the sample size increases, the histogram of the means will converge to a normal distribution due to the central limit theorem.

# %%
# Set up the figure
fig, axs = plt.subplots(4, 1, figsize=(15, 12))

# Set up the values of N
N_values = [1, 4, 9, 16]

# Draw the histograms for each value of N
for N, label in zip(N_values, ['1 samples', '4 samples', '9 samples', '16 samples']):
  r_norm = rv_norm.rvs(size=(1000, N))
  mean_norm = np.mean(r_norm, axis=1)
  
  r_expon = rv_expon.rvs(size=(1000, N))
  mean_expon = np.mean(r_expon, axis=1)

  r_chi2 = rv_chi2.rvs(size=(1000, N))
  mean_chi2 = np.mean(r_chi2, axis=1)
  
  r_uniform = rv_uniform.rvs(size=(1000, N))
  mean_uniform = np.mean(r_uniform, axis=1)


  # Plot the histogram
  axs[0].hist(mean_norm, bins=30, density=True, alpha=0.3, label=label)
  axs[1].hist(mean_expon, bins=30, density=True, alpha=0.3, label=label)
  axs[2].hist(mean_chi2, bins=30, density=True, alpha=0.3, label=label)
  axs[3].hist(mean_uniform, bins=30, density=True, alpha=0.3, label=label)

axs[0].set_title('Averaged normal distribution')
axs[1].set_title('Averaged exponential distribution')

for ax in axs.flat:
    ax.legend()

plt.show()

# %% [markdown]
# # Arbitrary distribution sampling
#
# Sometimes it may happen, that we need to sample from a custom distribution, not implemented in any standard library. There exist a simple algorithm for such sampling, provided that the distribution is bounded (pdf has finite support and maximum).
#
#
# #### Accept-rejection sampling
# Let the distribution be given by the pdf $g(x)$ and defined at interval $[a,b]$. In addition, let $M$ be the supremum of $g(x)$.
#
# 1. Take a sample $t$ from the uniform distribution at the interval $[a,b]$,
# 2. Take a sample $u$ from the uniform distribution at the interval $[0,M]$,
# 3. If $g(t) > u$ we accept $t$ as a sample taken from the original distribution. If not, we go back to 1.
#
# ## Ex 4.
# Implement function accept_rejection_sampling(dist, size = 1) which samples from any bounded distribution on the [0,1] interval.

# %% [markdown]
# ### Comment
#
# This code is defining a function ***accept_rejection_sampling(dist, size = 1)*** that uses the accept-rejection method to generate samples from any bounded distribution on the [0,1] interval.
#
# The function accepts two arguments, the distribution function dist and the number of samples to generate size.
#
# It first finds the maximum value of the distribution within the bounding box (interval [0,1]) by taking the maximum value of the input distribution dist.
#
# Then it initializes an empty list 'samples' to store the accepted samples.
#
# The function enters a while loop, where it will continue to generate samples until the number of accepted samples equals the desired size.
#
# It generates a random x value between 0 and 1, and a random y value between 0 and max_val, the maximum value of the distribution.
#
# Then it uses numpy's interp method to interpolate the value of the distribution at the sampled x point.
#
# If the randomly generated y value is less than the interpolated distribution value, the sample is accepted and appended to the samples list.
#
# The function returns the accepted samples.
#
# The code is also using the toy_dist function to generate a toy distribution, it's sampling from it using the accept_rejection_sampling function, and then it's plotting the toy_dist and the samples using matplotlib.
#
# The accept-rejection method is a general method for generating samples from any distribution for which we can easily generate samples from a bounding distribution. This is a powerful method, but it can be very computationally expensive, especially if the distribution has low probability density in some regions.

# %%
import random

def toy_dist(x):
    C = 1/3 - np.exp(-4)/4 + 1/4
    return (x**2 + np.exp(-4*x)) / C 

x = np.linspace(0,1,1000)

def accept_rejection_sampling(dist, size=1):
    # Find the maximum value of the distribution within the bounding box
    max_val = np.max(dist)

    # Initialize an array to store the samples
    samples = []

    # Sample until we have the desired number of samples
    while len(samples) < size:
        # Sample uniformly from the bounding box
        x = np.random.uniform(0, 1)
        y = np.random.uniform(0, max_val)

        # Interpolate the value of the distribution at the sampled point
        dist_val = np.interp(x, np.linspace(0, 1, len(dist)), dist)

        # Accept the sample with probability equal to the value of the distribution at that point, normalized by the maximum value of the distribution
        if y < dist_val:
            samples.append(x)

    return samples


samples = accept_rejection_sampling(toy_dist(x), size = 10000)

fig, ax = plt.subplots(1, 1)
ax.plot(x, toy_dist(x), 'r-', lw=5, alpha=0.6, label='toy pdf')
ax.hist(samples, density=True, histtype='stepfilled', alpha=0.2, bins = x[::40], label = "sampled")
ax.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# # Probability space matters!
# ## Ex 5
# Sample 2000 points from the unit disk. Do it in following ways:
# 1. Assume uniform distribution of radius (0,1) and argument (0,2$\pi$),
# 2. Assume uniform distribution of x and y coordinate (-1,1). Drop values laying outside of the disk.
# Explain differences. between 1. and 2. Then:
# 3. Modify the solution of point 1. by changing the distribution of the radius in such a way, that we result in 2D distribution from 2.

# %% [markdown]
# ### Comment
#
# The first method of generating points in the unit disk assumes that the radius of the point is uniformly distributed between 0 and 1, and the argument (angle) is uniformly distributed between 0 and 2π. This results in a non-uniform distribution of points within the unit disk, with more points concentrated near the center and fewer points near the edge.
#
# The second method of generating points in the unit disk assumes that the x and y coordinates of the point are uniformly distributed between -1 and 1. Points that fall outside of the unit disk are then dropped. This results in a uniform distribution of points within the unit disk.
#
# To modify the first method to result in a uniform distribution of points within the unit disk, we can change the distribution of the radius to be proportional to the square root of the radius, instead of being uniform. This is because if we integrate the probability density function of a uniform distribution over the area of the unit disk, the result would be a non-uniform distribution of points. By instead sampling the radius with a probability density function that is proportional to the square root of the radius, the integral over the area of the unit disk results in a uniform distribution of points.

# %%
bins = 30

print("Version 1")

random_radius = uniform.rvs(loc = 0,scale = 1 ,size=2000)
random_angle = uniform.rvs(loc = 0,scale = 2*np.pi ,size=2000)

fig, axs = plt.subplots(1, 3,figsize=(15, 5))

plt.subplot(1,3,1)
plt.xlabel("x")
plt.ylabel("y")
plt.scatter(random_radius*np.cos(random_angle),random_radius*np.sin(random_angle),alpha=0.2)

plt.subplot(1,3,2)
plt.xlabel("arg")
plt.ylabel("counts")
plt.hist(random_angle,bins=bins,alpha=0.2)

plt.subplot(1,3,3)
plt.xlabel("x")
plt.ylabel("counts")
plt.hist(x,bins=bins,alpha=0.2)

plt.show()
# Out:
# Version 1

# %% [markdown]
# ###Comment
# In version 1, we are assuming a uniform distribution of radius and argument, which means that any point within the unit disk has an equal probability of being chosen. In version 2, we are assuming a uniform distribution of x and y coordinates between -1 and 1, and only keeping the points that fall within the unit disk. The main difference is that version 2 samples points from a rectangular region and then filters out the points that fall outside of the unit disk, whereas version 1 samples points directly from the unit disk.
#
# To modify version 1 to result in the same 2D distribution as version 2, we can change the distribution of radius to be non-uniform. One way to do this is to use a distribution that is proportional to the square root of the radius. This way, the probability of a point being chosen is proportional to the area of the circle it is on, which results in a uniform distribution of points within the unit disk.

# %%
bins = 30

print("Version 2")

random_x = uniform.rvs(-1,2,2000)
random_y = uniform.rvs(-1,2,2000)
ind = np.where(random_x**2 + random_y**2 <=1)
random_x = random_x[ind]
random_y = random_y[ind]
fig, axs = plt.subplots(1, 3,figsize=(15, 5))

plt.subplot(1,3,1)
plt.xlabel("x")
plt.ylabel("y")
plt.scatter(random_x,random_y,alpha=0.2)

plt.subplot(1,3,2)
plt.xlabel("x")
plt.ylabel("counts")
plt.hist(random_x,bins=bins,alpha=0.2)

plt.subplot(1,3,3)
plt.xlabel("y")
plt.ylabel("counts")
plt.hist(random_y,bins=bins,alpha=0.2)

plt.show()
# Out:
# Version 2

# %% [markdown]
# Here goes your explanation
#
#
# In version 1, points are sampled from a uniform distribution of radius (0,1) and argument (0,2π), and then the x and y coordinates of the points are calculated using trigonometric functions. This results in a uniform distribution of points within the unit disk, with a higher density of points near the center of the disk and a lower density of points near the edges.
#
# In version 2, points are sampled from a uniform distribution of x and y coordinates (-1,1) and then points outside of the unit disk are dropped. This also results in a uniform distribution of points within the unit disk, but with a constant density of points throughout the disk, as opposed to the non-uniform density in version 1.

# %% [markdown]
# ### Comment
# In version 1, we sample points from the unit disk by assuming a uniform distribution of radius and argument. This means that all points within the unit disk are equally likely to be sampled. In version 2, we sample points by assuming a uniform distribution of the x and y coordinates within a square bounding box that encloses the unit disk. Points outside of the unit disk are then dropped. The difference between these two methods is that in version 1, all points within the unit disk are equally likely to be sampled, while in version 2, points near the center of the unit disk are more likely to be sampled than points near the edge.
#
# In version 3, we modify the solution of version 1 by changing the distribution of the radius to a square root distribution. This results in a 2D distribution that is uniform within the unit disk. The reason for this is that the area of a circle is proportional to the square of its radius, so a uniform distribution of radius will result in more points near the edge of the disk and less points near the center. By using a square root distribution, the probability density of points is proportional to the area of the circle, resulting in a uniform distribution within the unit disk.

# %%
bins = 30

print("Version 3")

random_radius = np.sqrt(uniform.rvs(loc = 0,scale = 1 ,size=2000))
random_angle = uniform.rvs(loc = 0,scale = 2*np.pi ,size=2000)
fig, axs = plt.subplots(1, 3,figsize=(15, 5))

plt.subplot(1,3,1)
plt.xlabel("x")
plt.ylabel("y")
plt.scatter(random_radius*np.cos(random_angle),random_radius*np.sin(random_angle),alpha=0.2)

plt.subplot(1,3,2)
plt.xlabel("arg")
plt.ylabel("counts")
plt.hist(random_angle,bins=bins,alpha=0.2)

plt.subplot(1,3,3)
plt.xlabel("x")
plt.ylabel("counts")
plt.hist(random_radius,bins=bins,alpha=0.2)

plt.show()
# Out:
# Version 3

# %% [markdown]
# ## Application: Laplace equation, Dirichlet boundary conditions
#
# #### Monte-Carlo procedure for solving 2D Laplace equation with Dirichlet boundary conditions
# 1. Start in a random position inside the boundaries,
# 2. With an equal probability move up/down/right/left until you hit the boundary,
# 3. After hitting the boundary we take the value $v_{b}$ of the function in the hitting point. We update the values of all points along the just finished random walk using the formula:
# $$ v_{new} = \dfrac{nv_{old} + v_{b}}{n+1}, $$
# where $n$ is a number of random walks which have already passed through this point.
# 4. Finish if the desired precision is achieved. If not, go back to 1.
#
#
# A theory behind the above procedure can be found here:
# https://www.uzh.ch/cmsssl/physik/dam/jcr:d559688c-1e7f-44ca-9fbe-aab0755c0b6e/empp18_MC_Markov.pdf

# %% [markdown]
# ## Ex 6
# Implement the method described above and solve numerically given Dirichlet problem. Plot few intermediate steps.

# %%
S = 100 # Decrease if computations take too long
plane = np.zeros((S,S))
plane_counts = np.zeros((S,S))
plane[0] = np.cos(np.linspace(-1.5,1.5,S)*2*np.pi)
plane[-1] = -np.cos(np.linspace(-1,1,S)*2*np.pi)
plane[:,0] = np.cos(np.linspace(-0.5,0.5,S)*2*np.pi)
plane[:,-1] = -2+np.linspace(-1,1,S)**2

# %%
plt.figure(figsize=(10,15))
plt.title("0 walks")
plt.imshow(plane)

# %% [markdown]
# ### Comment
#
# The above code is an implementation of the method of random walks for solving the Dirichlet problem. The Dirichlet problem is a boundary value problem that involves finding a function that satisfies certain boundary conditions. The method of random walks is an iterative method that involves repeatedly sampling random walks on the plane until the desired precision is achieved.
#
# In this implementation, the size of the plane is set to 100, and the plane and plane_counts arrays are initialized. The boundary conditions are set on the edges of the plane. The desired precision is set to 1e-3, and the number of random walks is initialized to 0. The code then enters a while loop that performs the random walks until the desired precision is achieved.
#
# At each iteration, the code chooses a random starting position inside the boundaries, and performs a random walk until the boundary is reached. If the boundary is reached, the values of the points along the random walk are updated. The number of random walks is then incremented, and the intermediate solution is stored in the planes list.
#
# Once the desired precision is achieved, the code plots the intermediate solutions stored in the planes list, with the number of walks as the title of each subplot. The final output is a series of plots that show the evolution of the solution as the number of random walks increases.

# %%
# # Set the size of the plane and initialize the plane and plane_counts arrays
# S = 100
# plane = np.zeros((S,S))
# plane_counts = np.zeros((S,S))
# plane[0] = np.cos(np.linspace(-1.5,1.5,S)*2*np.pi)
# plane[-1] = -np.cos(np.linspace(-1,1,S)*2*np.pi)
# plane[:,0] = np.cos(np.linspace(-0.5,0.5,S)*2*np.pi)
# plane[:,-1] = -2+np.linspace(-1,1,S)**2

# # Set the desired precision and initialize the number of random walks
# precision = 1e-3
# num_walks = 0

# # Initialize a list to store the number of random walks at each iteration
# walks = []

# # Initialize a list to store the intermediate solutions at each iteration
# planes = []

# # Perform the random walks until the desired precision is achieved
# while True:
#   # Choose a random starting position inside the boundaries
#   x = np.random.randint(1, S-1)
#   y = np.random.randint(1, S-1)
  
#   # Perform a random walk until the boundary is reached
#   while True:
#     # Choose a random direction with equal probability
#     direction = np.random.choice(['up', 'down', 'left', 'right'])
#     if direction == 'up':
#       y += 1
#     elif direction == 'down':
#       y -= 1
#     elif direction == 'left':
#       x -= 1
#     elif direction == 'right':
#       x += 1
    
#     # If the boundary is reached, update the values of the points along the random walk
#     if x == 0 or x == S-1 or y == 0 or y == S-1:
#       boundary_value = plane[y][x]
#       x_indices, y_indices = np.where(plane == boundary_value)
#       for i in range(len(x_indices)):
#         x_index = x_indices[i]
#         y_index = y_indices[i]
#         plane[y_index][x_index] = (num_walks*plane[y_index][x_index] + boundary_value)/(num_walks+1)
#         plane_counts[y_index][x_index] += 1
#       break
      
#   # Update the number of random walks
#   num_walks += 1
  
#   # Store the number of random walks and the intermediate solution
#   walks.append(num_walks)
#   planes.append(plane.copy())
  
#   # Check if the desired precision has been achieved
#   max_difference = np.max(np.abs(plane - plane_counts))
#   if max_difference <= precision:
#     break

# # Set the number of rows and columns for the subplots
# nrows = 3
# ncols = 3

# # Set the size of the figure
# plt.figure(figsize=(15, 15))

# # Iterate through the intermediate solutions
# for i, plane in enumerate(planes):
#   # Set the subplot
#   plt.subplot(nrows, ncols, i+1)
#   # Plot the solution
#   plt.imshow(plane)
#   # Set the title
#   plt.title("{} walks".format(walks[i]))

# # Show the plot
# plt.show()

# %%
#Animation code for testing purposes. May not work on your machine.


# %matplotlib qt

import matplotlib.animation as animation 

fig = plt.figure()
plt.title("0 walks")
im = plt.imshow(planes[0])
im.set_array(planes[0])

# function to update figure
def updatefig(j):
    # set the data in the axesimage object
    im.set_array(planes[j])
    plt.title("{0} walks".format(walks[j]))
    return [im]
# kick off the animation
ani = animation.FuncAnimation(fig, updatefig, frames=range(1000), interval=1000)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-62-cabd144dbafa> in <module>
#       2
#       3
# ----> 4 get_ipython().run_line_magic('matplotlib', 'qt')
#       5
#       6 import matplotlib.animation as animation
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2312                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2313             with self.builtin_trap:
# -> 2314                 result = fn(*args, **kwargs)
#    2315             return result
#    2316
#
# <decorator-gen-101> in matplotlib(self, line)
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
# ...
